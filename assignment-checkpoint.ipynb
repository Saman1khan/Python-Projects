# %%
list_a = [1,2,3]
list_b = [4,5,6]
list_c = [10,20,30]
list_d = [11,21,31]
w= 0
x= 0
y= 0
z= 0
h=0 

for i in range(len(list_a)):
        w = w + (list_a[i] * list_c[i])
        x = x + (list_a[i] * list_d[i])
for i in range(len(list_b)):
        y = y + (list_b[i] * list_c[i])
        z = z + (list_b[i] * list_d[i])
        
        
matrix = [w,x,y,z]
print(matrix)
# Out:
# [140, 146, 320, 335]
